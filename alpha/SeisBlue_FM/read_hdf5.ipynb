# %%
import h5glance 
import h5py
c=0
with h5py.File("./dataset/2022_ETBATS_2022-09_train.hdf5", 'r') as f:
#     print(list(f.keys()))
    for event in f.values():
        c += len(event['instances'].keys())
print(c)



#     print(list(f['2018-02-14T21:43:32.900000'].attrs())[0])
# Out:
# 7441

# %%
# !h5glance ./dataset/2018_HL_2018-02_test.hdf5 2018-02-14T21:43:32.900000/instances --attrs
# Out:
# dataset\2018_HL_2018-02_test.hdf5/2018-02-14T21:43:32.900000/instances
# ├2018-02-14T21:43:35.200000.HL.T020
# │ ├1 attributes:
# │ │ └id: '2018-02-14T21:43:35.200000.HL.T020'
# │ ├inventory
# │ │ └2 attributes:
# │ │   ├network: 'HL'
# │ │   └station: 'T020'
# │ ├labels
# │ │ ├SeisPolar
# │ │ │ ├1 attributes:
# │ │ │ │ └tag: 'SeisPolar'
# │ │ │ ├data	[float32: 3]
# │ │ │ └pick
# │ │ │   └9 attributes:
# │ │ │     ├azimuth: 110.0
# │ │ │     ├confidence: 0.6796561479568481
# │ │ │     ├phase: 'P'
# │ │ │     ├pick_id: 'smi:local/b05249c4-8e19-44c7-92cf-c15cdc439dea'
# │ │ │     ├polarity: 'undecidable'
# │ │ │     ├raw_polarity: 'positive'
# │ │ │     ├tag: 'SeisPolar'
# │ │ │     ├takeoff_angle: 166.0
# │ │ │     └time: '2018-02-14T21:43:35.200000'
# │ │ └manual
# │ │   ├1 attributes:
# │ │   │ └tag: 'manual'
# │ │   ├data	[int64: 3]
# │ │   └pick
# │ │     ├7 attributes:
# │ │     │ ├azimuth: 110.0
# │ │     │ ├phase: 'P'
# ...
