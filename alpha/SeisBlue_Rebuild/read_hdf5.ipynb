# %%
import h5glance 
import h5py
import os
os.environ["HDF5_USE_FILE_LOCKING"] = "FALSE"
with h5py.File("./dataset/HP_2017-02-01.hdf5", 'r') as f:
    print(len(f.keys()))
    print(list(f.keys()))
# Out:
# 1787
# ...

# %%
# !h5glance ./dataset/HP_2017-02-01.hdf5 2017-02-01T03:26:19.460000.HP.HP05 --attrs
# Out:
# dataset\HP_2017-02-01.hdf5/2017-02-01T03:26:19.460000.HP.HP05
# ├2 attributes:
# │ ├dataset: 'HP_2017-02-01.hdf5'
# │ └datasetpath: '/usr/src/app/dataset/HP_2017-02-01.hdf5'
# ├features
# │ ├1 attributes:
# │ │ └channel: 'HHE,HHN,HHZ'
# │ └data	[float64: 3 × 2048]
# ├inventory
# │ └2 attributes:
# │   ├network: 'HP'
# │   └station: 'HP05'
# ├labels
# │ └manual
# │   ├2 attributes:
# │   │ ├phase: 'PSN'
# │   │ └tag: 'manual'
# │   ├data	[float64: 3 × 2048]
# │   └picks
# │     ├P
# │     │ ├4 attributes:
# │     │ │ ├phase: 'P'
# │     │ │ ├snr: 0.214
# │     │ │ ├tag: 'manual'
# │     │ │ └time: '2017-02-01T03:26:36.420000'
# │     │ └inventory
# │     │   └2 attributes:
# │     │     ├network: 'HP'
# │     │     └station: 'HP05'
# │     └S
# │       ├4 attributes:
# │       │ ├phase: 'S'
# │       │ ├snr: nan
# │       │ ├tag: 'manual'
# │       │ └time: '2017-02-01T03:26:38.920000'
# │       └inventory
# │         └2 attributes:
# │           ├network: 'HP'
# ...

# %%
with h5py.File("./dataset/HP_2017-02-01.hdf5", 'r') as f:
    pick = f['2017-02-01T01:58:09.020000.HP.HP06/labels/PSN/picks/P'].name
    print(pick)
# Out:
# /2017-02-01T01:58:09.020000.HP.HP06/labels/PSN/picks/P
